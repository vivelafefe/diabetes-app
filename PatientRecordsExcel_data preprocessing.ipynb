# %% [markdown]
# # Patient records from Excel_data preprocessing

# %% [markdown]
# In addition to the Diabet app, carb intake, blood glucose levels and insulin delivery were recorded in Excel. This data was also used for further analysis.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Data exploration

# %% [markdown]
# The data recorded in Excel was the most disorganised. There were numerous empty rows and missing values, unnecessary columns, times documented descriptively (e.g. waking-up, dinner, etc.), and typos.

# %%
pr = pd.read_csv('PatientRecords_Excel.csv')

# %%
pr.head(20)
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3       Unnamed: 4 Unnamed: 5  \
# 0         NaN        NaN        NaN        NaN              NaN        NaN
# 1         NaN        NaN        NaN        NaN              NaN        NaN
# 2         NaN       date       time        NaN  BG, before meal          1
# 3         NaN        NaN        NaN        NaN              NaN        NaN
# 4         NaN        NaN        NaN  waking up              NaN        NaN
# 5         NaN        NaN        NaN        NaN              NaN        NaN
# 6        june  6/10/2019        NaN  breakfast              NaN        NaN
# 7         NaN        NaN        NaN        NaN              NaN        NaN
# 8         NaN  6/10/2019        NaN      lunch              NaN        NaN
# 9         NaN        NaN        NaN        NaN              NaN        NaN
# 10        NaN  6/10/2019        NaN     dinner              NaN        NaN
# 11        NaN        NaN        NaN        NaN              NaN        NaN
# 12        NaN        NaN        NaN      total              NaN        NaN
# 13        NaN        NaN        NaN        NaN              NaN        NaN
# 14        NaN        NaN        NaN        NaN              NaN        NaN
# 15        NaN        NaN        NaN  waking up              4.4        NaN
# 16        NaN        NaN        NaN        NaN              NaN        NaN
# 17        NaN  6/11/2019        NaN  breakfast                5        NaN
# 18        NaN        NaN        NaN        NaN              NaN        NaN
# 19        NaN  6/11/2019        NaN      lunch              3.8        NaN
#
#     Unnamed: 6  Unnamed: 7  Unnamed: 8 Unnamed: 9  ... Unnamed: 43  \
# 0          NaN         NaN         NaN        NaN  ...         NaN
# 1          NaN         NaN         NaN        NaN  ...         NaN
# 2          2.0         3.0         4.0          5  ...         NaN
# 3          NaN         NaN         NaN        NaN  ...         NaN
# 4          NaN         NaN         NaN        NaN  ...         NaN
# 5          NaN         NaN         NaN        NaN  ...         NaN
# 6          NaN         NaN         NaN        NaN  ...         NaN
# 7          NaN         NaN         NaN        NaN  ...         NaN
# 8          NaN         NaN         NaN        NaN  ...         NaN
# 9          NaN         NaN         NaN        NaN  ...         NaN
# 10         NaN         NaN         NaN        NaN  ...         NaN
# 11         NaN         NaN         NaN        NaN  ...         NaN
# 12         NaN         NaN         NaN        NaN  ...         NaN
# 13         NaN         NaN         NaN        NaN  ...         NaN
# 14         NaN         NaN         NaN        NaN  ...         NaN
# 15         NaN         NaN         NaN        NaN  ...         NaN
# 16         NaN         NaN         NaN        NaN  ...         NaN
# 17         NaN         NaN         NaN        NaN  ...         NaN
# 18         NaN         NaN         NaN        NaN  ...         NaN
# 19         NaN         NaN         NaN        NaN  ...         NaN
#
#    Unnamed: 44 Unnamed: 45    Unnamed: 46 Unnamed: 47 Unnamed: 48 Unnamed: 49  \
# 0          NaN         NaN            NaN         NaN         NaN         NaN
# 1          NaN         NaN  ESTIMATED UC          NaN         NaN         NaN
# 2      cur/est         NaN      UCProtein      UCCarb      UC P+C         NaN
# 3          NaN         NaN            NaN         NaN         NaN         NaN
# 4          NaN         NaN            NaN         NaN         NaN         NaN
# 5          NaN         NaN            NaN         NaN         NaN         NaN
# 6          NaN         NaN            NaN         NaN         NaN         NaN
# 7          NaN         NaN            NaN         NaN         NaN         NaN
# 8          NaN         NaN            NaN         NaN         NaN         NaN
# 9          NaN         NaN            NaN         NaN         NaN         NaN
# 10         NaN         NaN            NaN         NaN         NaN         NaN
# 11         NaN         NaN            NaN         NaN         NaN         NaN
# 12         NaN         NaN            NaN         NaN         NaN         NaN
# 13         NaN         NaN            NaN         NaN         NaN         NaN
# 14         NaN         NaN            NaN         NaN         NaN         NaN
# 15         NaN         NaN            NaN         NaN         NaN         NaN
# 16         NaN         NaN            NaN         NaN         NaN         NaN
# 17         NaN         NaN            NaN         NaN         NaN         NaN
# 18         NaN         NaN            NaN         NaN         NaN         NaN
# 19         NaN         NaN            NaN         NaN         NaN         NaN
#
#    Unnamed: 50 Unnamed: 51 Unnamed: 52
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         NaN         NaN         NaN
# 19         NaN         NaN         NaN
#
# [20 rows x 53 columns]

# %% [markdown]
# ### 2. Data cleaning

# %% [markdown]
# All columns with empty or unnecessary values were dropped, and the remaining columns were appropriately renamed. Subsequently, empty rows were removed and any missing or improperly formatted dates were replaced with appropriate values and converted to datetime objects. The values in the numeric columns were converted into the appropriate data types. Errors occurring due to manual data entries were fixed accordingly.

# %%
#removing empty NaN columns
pr.dropna(axis=1,how='all',inplace=True)
pr.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3       Unnamed: 4 Unnamed: 5  \
# 0        NaN        NaN        NaN        NaN              NaN        NaN
# 1        NaN        NaN        NaN        NaN              NaN        NaN
# 2        NaN       date       time        NaN  BG, before meal          1
# 3        NaN        NaN        NaN        NaN              NaN        NaN
# 4        NaN        NaN        NaN  waking up              NaN        NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8 Unnamed: 9  ...             Unnamed: 40  \
# 0         NaN         NaN         NaN        NaN  ...                     NaN
# 1         NaN         NaN         NaN        NaN  ...  changes by CURRENT DAY
# 2         2.0         3.0         4.0          5  ...               UCProtein
# 3         NaN         NaN         NaN        NaN  ...                     NaN
# 4         NaN         NaN         NaN        NaN  ...                     NaN
#
#   Unnamed: 41 Unnamed: 42 Unnamed: 44    Unnamed: 46 Unnamed: 47 Unnamed: 48  \
# 0         NaN         NaN         NaN            NaN         NaN         NaN
# 1         NaN         NaN         NaN  ESTIMATED UC          NaN         NaN
# 2      UCCarb      UC P+C     cur/est      UCProtein      UCCarb      UC P+C
# 3         NaN         NaN         NaN            NaN         NaN         NaN
# 4         NaN         NaN         NaN            NaN         NaN         NaN
#
#   Unnamed: 50 Unnamed: 51 Unnamed: 52
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
#
# [5 rows x 47 columns]

# %%
#removing columns with unnecessary information
pr.drop(columns=pr.iloc[:, np.r_[0,5:14,15:18,19,21:len(pr.columns)]],inplace=True)
pr.head()
# Out:
#   Unnamed: 1 Unnamed: 2 Unnamed: 3       Unnamed: 4  \
# 0        NaN        NaN        NaN              NaN
# 1        NaN        NaN        NaN              NaN
# 2       date       time        NaN  BG, before meal
# 3        NaN        NaN        NaN              NaN
# 4        NaN        NaN  waking up              NaN
#
#                   Unnamed: 14 Unnamed: 18 Unnamed: 20
# 0                         NaN         NaN         NaN
# 1                         NaN     insulin         NaN
# 2  net carb without fibre, g         Base       Short
# 3                         NaN         NaN         NaN
# 4                         NaN           7         0.5

# %%
#renaming columns
pr.rename(columns={pr.columns[0]:'Date',pr.columns[1]:'Time',pr.columns[2]:'PartOfTheDay',pr.columns[3]:'BG',
                  pr.columns[4]:'DV',pr.columns[5]:'bID',pr.columns[6]:'shID'},inplace=True)
pr.head()
# Out:
#    Date  Time PartOfTheDay               BG                          DV  \
# 0   NaN   NaN          NaN              NaN                         NaN
# 1   NaN   NaN          NaN              NaN                         NaN
# 2  date  time          NaN  BG, before meal  net carb without fibre, g
# 3   NaN   NaN          NaN              NaN                         NaN
# 4   NaN   NaN    waking up              NaN                         NaN
#
#        bID   shID
# 0      NaN    NaN
# 1  insulin    NaN
# 2     Base  Short
# 3      NaN    NaN
# 4        7    0.5

# %%
#creating a new DF keeping only the rows with 'PartOfTheDay' values 'waking up','breakfast','lunch','dinner' and 'night'
pr = pr[(pr['PartOfTheDay'] == 'waking up')|(pr['PartOfTheDay'] == 'breakfast')|(pr['PartOfTheDay'] == 'lunch')|
        (pr['PartOfTheDay'] == 'dinner')|(pr['PartOfTheDay'] == 'night')]
pr = pr.reset_index(drop=True)
pr.head()
# Out:
#         Date Time PartOfTheDay   BG   DV  bID shID
# 0        NaN  NaN    waking up  NaN  NaN    7  0.5
# 1  6/10/2019  NaN    breakfast  NaN  NaN  NaN    2
# 2  6/10/2019  NaN        lunch  NaN  NaN  NaN    3
# 3  6/10/2019  NaN       dinner  NaN  NaN    1    2
# 4        NaN  NaN    waking up  4.4  NaN    7  0.5

# %%
#filling in missing dates for CP 'waking up' & 'night'
for i in pr.index:
    if pr.loc[i,'PartOfTheDay'] == 'waking up':
        pr.loc[i,'Date'] = pr.loc[i+1,'Date']
    elif pr.loc[i,'PartOfTheDay'] == 'night':
        pr.loc[i,'Date'] = pr.loc[i-1,'Date']

# %%
#checking if there are missing dates
pr['Date'].isna().sum()
# Out:
# 0

# %%
#filling missing time values depending on PartOfTheDay
for i in pr.index:
    
    if pd.isnull(pr.at[i,'Time']):
        
        if pr.loc[i,'PartOfTheDay'] == 'waking up':
            pr.loc[i,'Time'] = '07-00'
        elif pr.loc[i,'PartOfTheDay'] == 'breakfast':
            pr.loc[i,'Time'] = '08-00'
        elif pr.loc[i,'PartOfTheDay'] == 'lunch':
            pr.loc[i,'Time'] = '13-00'
        elif pr.loc[i,'PartOfTheDay'] == 'dinner':
            pr.loc[i,'Time'] = '18-30'
        elif pr.loc[i,'PartOfTheDay'] == 'night':
            pr.loc[i,'Time'] = '22-00'

# %%
#checking if there are missing times
pr['Time'].isna().sum()
# Out:
# 0

# %%
#some of the time values were recorded in a 00-00/00-00 format
#creating a new value by keeping only the first part before /
pr.loc[pr['Time'].str.contains('/','Time'),'Time'] = pr['Time'].str.split('/')[0]

# %%
#concatenating the 'Date' and the 'Time' columns
pr['Date'] = pr['Date'] + ' ' + pr['Time']

# %%
#removing the 'Time' column
pr.drop(['Time','PartOfTheDay'],axis=1,inplace=True)

# %%
#preparing the 'Date' column for the data conversion, converting 00-00 time format into 00:00 
pr['Date'] = pr['Date'].str.replace('-',':')
pr.head()
# Out:
#               Date   BG   DV  bID shID
# 0  6/10/2019 07:00  NaN  NaN    7  0.5
# 1  6/10/2019 08:00  NaN  NaN  NaN    2
# 2  6/10/2019 13:00  NaN  NaN  NaN    3
# 3  6/10/2019 18:30  NaN  NaN    1    2
# 4  6/11/2019 07:00  4.4  NaN    7  0.5

# %%
#converting dtypes in the'Date' column into datetime type
pr['Date']= pd.to_datetime(pr['Date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/dateutil/parser/_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/dateutil/parser/_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: hour must be in 0..23
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:605, in pandas._libs.tslib.array_to_datetime()
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/_libs/tslibs/parsing.pyx:320, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/dateutil/parser/_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/dateutil/parser/_parser.py:651, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     650 except ValueError as e:
# --> 651     six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     653 if not ignoretz:
#
# File <string>:3, in raise_from(value, from_value)
#
# ParserError: hour must be in 0..23: 7/12/2019 24:00
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:616, in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime for "7/12/2019 24:00" at position 152
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/dateutil/parser/_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/dateutil/parser/_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: hour must be in 0..23
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# Cell In[16], line 2
#       1 #converting dtypes in the'Date' column into datetime type
# ----> 2 pr['Date']= pd.to_datetime(pr['Date'])
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066         result = arg.map(cache_array)
#    1067     else:
# -> 1068         values = convert_listlike(arg._values, format)
#    1069         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1070 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:438, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     436 assert format is None or infer_datetime_format
#     437 utc = tz == "utc"
# --> 438 result, tz_parsed = objects_to_datetime64ns(
#     439     arg,
#     440     dayfirst=dayfirst,
#     441     yearfirst=yearfirst,
#     442     utc=utc,
#     443     errors=errors,
#     444     require_iso8601=require_iso8601,
#     445     allow_object=True,
#     446 )
#     448 if tz_parsed is not None:
#     449     # We can take a shortcut since the datetime64 numpy array
#     450     # is in UTC
#     451     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py:2177, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2175 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2176 try:
# -> 2177     result, tz_parsed = tslib.array_to_datetime(
#    2178         data.ravel("K"),
#    2179         errors=errors,
#    2180         utc=utc,
#    2181         dayfirst=dayfirst,
#    2182         yearfirst=yearfirst,
#    2183         require_iso8601=require_iso8601,
#    2184         allow_mixed=allow_mixed,
#    2185     )
#    2186     result = result.reshape(data.shape, order=order)
#    2187 except OverflowError as err:
#    2188     # Exception is raised when a part of date is greater than 32 bit signed int
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:427, in pandas._libs.tslib.array_to_datetime()
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:683, in pandas._libs.tslib.array_to_datetime()
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:829, in pandas._libs.tslib._array_to_datetime_object()
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:819, in pandas._libs.tslib._array_to_datetime_object()
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/_libs/tslibs/parsing.pyx:320, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/dateutil/parser/_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1366     return parser(parserinfo).parse(timestr, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/dateutil/parser/_parser.py:651, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
# --> 651     six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     653 if not ignoretz:
#     654     ret = self._build_tzaware(ret, res, tzinfos)
#
# File <string>:3, in raise_from(value, from_value)
#
# ParserError: hour must be in 0..23: 7/12/2019 24:00 present at position 152

# %%
#fixing ParserError: hour must be in 0..23: 23.07.2019 24:00
pr.loc[pr['Date'].str.contains('24:'),'Date'] = pr['Date'].str.replace('24:','00:')

# %%
#converting dtypes in the'Date' column into datetime type
pr['Date']= pd.to_datetime(pr['Date'])
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:605, in pandas._libs.tslib.array_to_datetime()
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/_libs/tslibs/parsing.pyx:320, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/dateutil/parser/_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/dateutil/parser/_parser.py:643, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     642 if res is None:
# --> 643     raise ParserError("Unknown string format: %s", timestr)
#     645 if len(res) == 0:
#
# ParserError: Unknown string format: 16.09.2019 no lunch
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:616, in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime for "16.09.2019 no lunch" at position 536
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# Cell In[18], line 2
#       1 #converting dtypes in the'Date' column into datetime type
# ----> 2 pr['Date']= pd.to_datetime(pr['Date'])
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066         result = arg.map(cache_array)
#    1067     else:
# -> 1068         values = convert_listlike(arg._values, format)
#    1069         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1070 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:438, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     436 assert format is None or infer_datetime_format
#     437 utc = tz == "utc"
# --> 438 result, tz_parsed = objects_to_datetime64ns(
#     439     arg,
#     440     dayfirst=dayfirst,
#     441     yearfirst=yearfirst,
#     442     utc=utc,
#     443     errors=errors,
#     444     require_iso8601=require_iso8601,
#     445     allow_object=True,
#     446 )
#     448 if tz_parsed is not None:
#     449     # We can take a shortcut since the datetime64 numpy array
#     450     # is in UTC
#     451     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py:2177, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2175 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2176 try:
# -> 2177     result, tz_parsed = tslib.array_to_datetime(
#    2178         data.ravel("K"),
#    2179         errors=errors,
#    2180         utc=utc,
#    2181         dayfirst=dayfirst,
#    2182         yearfirst=yearfirst,
#    2183         require_iso8601=require_iso8601,
#    2184         allow_mixed=allow_mixed,
#    2185     )
#    2186     result = result.reshape(data.shape, order=order)
#    2187 except OverflowError as err:
#    2188     # Exception is raised when a part of date is greater than 32 bit signed int
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:427, in pandas._libs.tslib.array_to_datetime()
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:683, in pandas._libs.tslib.array_to_datetime()
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:829, in pandas._libs.tslib._array_to_datetime_object()
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:819, in pandas._libs.tslib._array_to_datetime_object()
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/_libs/tslibs/parsing.pyx:320, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/dateutil/parser/_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1366     return parser(parserinfo).parse(timestr, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/dateutil/parser/_parser.py:643, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     640 res, skipped_tokens = self._parse(timestr, **kwargs)
#     642 if res is None:
# --> 643     raise ParserError("Unknown string format: %s", timestr)
#     645 if len(res) == 0:
#     646     raise ParserError("String does not contain a date: %s", timestr)
#
# ParserError: Unknown string format: 16.09.2019 no lunch present at position 536

# %%
#fixing ParserError: Unknown string format: 16.09.2019 no lunch
pr.loc[pr['Date'].str.contains('no lunch'),'Date'] = pr['Date'].str.replace('no lunch','12:30')

# %%
#converting dtypes in the'Date' column into datetime type
pr['Date']= pd.to_datetime(pr['Date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/dateutil/parser/_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/dateutil/parser/_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: day is out of range for month
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:605, in pandas._libs.tslib.array_to_datetime()
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/_libs/tslibs/parsing.pyx:320, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/dateutil/parser/_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/dateutil/parser/_parser.py:651, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     650 except ValueError as e:
# --> 651     six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     653 if not ignoretz:
#
# File <string>:3, in raise_from(value, from_value)
#
# ParserError: day is out of range for month: 31.11.2019 07:00
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:616, in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime for "31.11.2019 07:00" at position 990
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/dateutil/parser/_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/dateutil/parser/_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: day is out of range for month
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# Cell In[20], line 2
#       1 #converting dtypes in the'Date' column into datetime type
# ----> 2 pr['Date']= pd.to_datetime(pr['Date'])
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066         result = arg.map(cache_array)
#    1067     else:
# -> 1068         values = convert_listlike(arg._values, format)
#    1069         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1070 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:438, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     436 assert format is None or infer_datetime_format
#     437 utc = tz == "utc"
# --> 438 result, tz_parsed = objects_to_datetime64ns(
#     439     arg,
#     440     dayfirst=dayfirst,
#     441     yearfirst=yearfirst,
#     442     utc=utc,
#     443     errors=errors,
#     444     require_iso8601=require_iso8601,
#     445     allow_object=True,
#     446 )
#     448 if tz_parsed is not None:
#     449     # We can take a shortcut since the datetime64 numpy array
#     450     # is in UTC
#     451     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py:2177, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2175 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2176 try:
# -> 2177     result, tz_parsed = tslib.array_to_datetime(
#    2178         data.ravel("K"),
#    2179         errors=errors,
#    2180         utc=utc,
#    2181         dayfirst=dayfirst,
#    2182         yearfirst=yearfirst,
#    2183         require_iso8601=require_iso8601,
#    2184         allow_mixed=allow_mixed,
#    2185     )
#    2186     result = result.reshape(data.shape, order=order)
#    2187 except OverflowError as err:
#    2188     # Exception is raised when a part of date is greater than 32 bit signed int
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:427, in pandas._libs.tslib.array_to_datetime()
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:683, in pandas._libs.tslib.array_to_datetime()
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:829, in pandas._libs.tslib._array_to_datetime_object()
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:819, in pandas._libs.tslib._array_to_datetime_object()
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/_libs/tslibs/parsing.pyx:320, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/dateutil/parser/_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1366     return parser(parserinfo).parse(timestr, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/dateutil/parser/_parser.py:651, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
# --> 651     six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     653 if not ignoretz:
#     654     ret = self._build_tzaware(ret, res, tzinfos)
#
# File <string>:3, in raise_from(value, from_value)
#
# ParserError: day is out of range for month: 31.11.2019 07:00 present at position 990

# %%
#fixing ParserError: day is out of range for month: 31.11.2019 07:00
#getting index positions of those dates
pr.loc[pr['Date'].str.contains('31.11.2019'),'Date']
# Out:
# 990    31.11.2019 07:00
# 991    31.11.2019 08:00
# 992    31.11.2019 13:00
# 993    31.11.2019 18:30
# 994    31.11.2019 22:00
# 995    31.11.2019 22:00
# Name: Date, dtype: object

# %%
#removing those rows and resetting the index
pr.drop(pr.index[990:996],inplace=True)

# %%
#resetting the index
pr = pr.reset_index(drop=True)

# %%
pr['Date']= pd.to_datetime(pr['Date'])

# %%
pr.head()
# Out:
#                  Date   BG   DV  bID shID
# 0 2019-06-10 07:00:00  NaN  NaN    7  0.5
# 1 2019-06-10 08:00:00  NaN  NaN  NaN    2
# 2 2019-06-10 13:00:00  NaN  NaN  NaN    3
# 3 2019-06-10 18:30:00  NaN  NaN    1    2
# 4 2019-06-11 07:00:00  4.4  NaN    7  0.5

# %%
pr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2891 entries, 0 to 2890
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2891 non-null   datetime64[ns]
#  1   BG      1253 non-null   object
#  2   DV      1193 non-null   object
#  3   bID     519 non-null    object
#  4   shID    1209 non-null   object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 113.1+ KB

# %%
#filling NaN with O in numeric columns
pr[['BG','DV','bID','shID']] = pr[['BG','DV','bID','shID']].fillna('0')

# %%
#converting to float numbers
pr[['BG','DV','bID','shID']] = pr[['BG','DV','bID','shID']].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 2
#       1 #converting to float numbers
# ----> 2 pr[['BG','DV','bID','shID']] = pr[['BG','DV','bID','shID']].astype(float)
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/internals/managers.py:450, in BaseBlockManager.astype(self, dtype, copy, errors)
#     449 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 450     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/internals/managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/internals/blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/dtypes/astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/dtypes/astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/dtypes/astype.py:170, in astype_nansafe(arr, dtype, copy, skipna)
#     166     raise ValueError(msg)
#     168 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169     # Explicit copy, or required since NumPy can't view from / to object.
# --> 170     return arr.astype(dtype, copy=True)
#     172 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '  -     '

# %%
#fixing ValueError: could not convert string to float: '  -     '
pr.loc[pr['BG'].str.contains('  -     '),:]
# Out:
#                    Date        BG DV bID shID
# 359 2019-08-17 03:30:00    -       0   2    0

# %%
pr.loc[359,'BG'] = '0'

# %%
pr[['BG','DV','bID','shID']] = pr[['BG','DV','bID','shID']].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 pr[['BG','DV','bID','shID']] = pr[['BG','DV','bID','shID']].astype(float)
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/internals/managers.py:450, in BaseBlockManager.astype(self, dtype, copy, errors)
#     449 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 450     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/internals/managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/internals/blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/dtypes/astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/dtypes/astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/dtypes/astype.py:170, in astype_nansafe(arr, dtype, copy, skipna)
#     166     raise ValueError(msg)
#     168 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169     # Explicit copy, or required since NumPy can't view from / to object.
# --> 170     return arr.astype(dtype, copy=True)
#     172 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '3*0,9DEXTR'

# %%
#fixing ValueError: could not convert string to float: '3*0,9DEXTR'
pr.loc[pr['bID'].str.contains('3*0,9DEXTR'),:]
# Out:
#                     Date   BG DV         bID shID
# 2615 2021-09-07 22:00:00  2.8  0  3*0,9DEXTR    0

# %%
pr.loc[2615,'bID'] = '0'

# %%
pr[['BG','DV','bID','shID']] = pr[['BG','DV','bID','shID']].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 pr[['BG','DV','bID','shID']] = pr[['BG','DV','bID','shID']].astype(float)
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/internals/managers.py:450, in BaseBlockManager.astype(self, dtype, copy, errors)
#     449 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 450     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/internals/managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/internals/blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/dtypes/astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/dtypes/astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/opt/anaconda3/envs/diabetesapp-env/lib/python3.9/site-packages/pandas/core/dtypes/astype.py:170, in astype_nansafe(arr, dtype, copy, skipna)
#     166     raise ValueError(msg)
#     168 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169     # Explicit copy, or required since NumPy can't view from / to object.
# --> 170     return arr.astype(dtype, copy=True)
#     172 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: 'no breakfast'

# %%
#fixing ValueError: could not convert string to float: 'no breakfast'
pr.loc[pr['shID'].str.contains('no breakfast'),:]
# Out:
#                    Date   BG    DV bID          shID
# 445 2019-01-09 09:00:00  4.3  5.53   0  no breakfast

# %%
pr.loc[445,'shID'] = '0'

# %%
pr[['BG','DV','bID','shID']] = pr[['BG','DV','bID','shID']].astype(float)

# %%
pr
# Out:
#                     Date   BG    DV  bID  shID
# 0    2019-06-10 07:00:00  0.0  0.00  7.0   0.5
# 1    2019-06-10 08:00:00  0.0  0.00  0.0   2.0
# 2    2019-06-10 13:00:00  0.0  0.00  0.0   3.0
# 3    2019-06-10 18:30:00  0.0  0.00  1.0   2.0
# 4    2019-06-11 07:00:00  4.4  0.00  7.0   0.5
# ...                  ...  ...   ...  ...   ...
# 2886 2021-08-24 07:00:00  2.8  0.00  3.0   0.0
# 2887 2021-08-24 07:00:00  5.1  4.51  0.0   3.0
# 2888 2021-08-24 07:00:00  3.9  7.85  0.0   3.0
# 2889 2021-08-24 07:00:00  4.7  7.08  0.0   3.0
# 2890 2021-08-24 22:00:00  5.9  0.00  1.5   0.0
#
# [2891 rows x 5 columns]

# %%
#Converting dietary value to bread units
pr['DV'] = pr['DV']/10

# %%
pr.to_csv('PatientRecords_E.csv',index=False)
